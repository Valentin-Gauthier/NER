# %%
import importlib
import pandas as pd

# %%
# LOAD THE DATAS
DATAS = pd.read_excel("C:\\Users\\valen\\Documents\\Informatique-L3\\Stage_NER\\NER\\src\\Ressources\\20231101_raw.xlsx")

# %% [markdown]
# # 🧩 CasEN Configuration
#
#  IMPORTANTS : Don't forget to check the casen_config.yaml file !
#
# | Parameter         | Type             | Description                                                                                                 |
# |------------------|-------------------|-------------------------------------------------------------------------------------------------------------|
# | `data`           | `DataFrame \| str`| Input data loaded from an Excel file.                                                                       |
# | `remove_MISC`    | `bool`            | If `True`, removes all MISC tags from the output.                                                           |
# | `single_corpus`  | `bool`            | If `True`, produces a single corpus file; otherwise, one per entry in the `data`.                           |
# | `run_casEN`      | `bool`            | If `True`, executes CasEN. If `False`, assumes data already exists in `corpus_folder` and `result_folder`.  |
# | `logging`        | `bool`            | Enables logging of key function execution times to a log file.                                              |
# | `log_folder`     | `str`             | Path to the folder that will contain the log file.                                                          |
# | `timer`          | `bool`            | Displays execution time in the console during runtime.                                                      |
# | `verbose`        | `bool`            | Enables detailed debug output in the console.                                                               |

# %%
from tools import casen_config
importlib.reload(casen_config)
from tools.casen_config import CasenConfig

# ========================= CASEN EXEMPLE ===================== 
c = CasenConfig(
    run_casen= True,
    single_corpus= True,
    production_mode = True, # light_mode True : 5432714 bytes VS False : 8422013 bytes 
    remove_misc= True,
    logging= False,
    timer= True,
    archiving_result= False,
    verbose= True
)

casen_df = c.run(DATAS)
casen_df.head()
# Out:
# [load config] Config Loaded sucessfuly !
# load_config in : 0.07s
# load_data in : 0.00s
# [prepare folder] Empty folder : C:\Users\valen\Documents\Informatique-L3\Stage_NER\NER\src\Results\Corpus
# [prepare folder] Empty folder : C:\Users\valen\Documents\Informatique-L3\Stage_NER\NER\src\Results\CasEN\Res_CasEN
# [generate file(s)] Single corpus file generated: C:\Users\valen\Documents\Informatique-L3\Stage_NER\NER\src\Results\Corpus\corpus.txt
# [generate file(s)] Missing description : 3657
# generate_corpus in : 0.42s
# {'event', 'ref', 'productName', 'place', 'extent', 'gYear', 'placeName', 'date', 'orgName', 'time', 'roleName', 'vieuxSigle', 'measure', 'timePeriod', 'product', 'nationality', 'datePeriod', 'persName', 'name', 'geogName', 'geogFeat', 'org', 'demonym', 'adress'}
# corpus.txt
# C:\Users\valen\Documents\Informatique-L3\Stage_NER\NER\src\Results\Corpus		 -> results in : C:\Users\valen\Documents\Informatique-L3\Stage_NER\NER\src\Results\CasEN\Res_CasEN
# 1 files to process with CasEN in  C:\Users\valen\Documents\Informatique-L3\Stage_NER\NER\src\Results\Corpus
#
# ✅ Transformation réussie. Résultat enregistré dans 'C:\Users\valen\Documents\Informatique-L3\Stage_NER\NER\src\Results\CasEN\Res_CasEN\corpus.result.txt'.
# run_casEN_on_corpus in : 324.58s
# [casen] 1 file(s) loaded
# load_files in : 0.00s
# get_entities in : 2.94s
# CasEN in : 2.98s
# CasEN : (13233, 9)
# Memory usage : 5432714 bytes
# run in : 327.59s
#              NER NER_label method        main_graph      second_graph  \
# 0           Nora       PER  casEN  grfpersGenerique
# 1         Marcel       PER  casEN  grfpersGenerique
# 2  Tristan Garil       PER  casEN  grfpersPrenomNom      grftagPrenom
# 3        galerie       ORG  casEN   grforgProximite
# 4       Delandin       ORG  casEN       grforgSeule  grfpersGenerique
#
#         third_graph  file_id  entity_start  entity_end
# 0                          0           206         210
# 1                          0           353         359
# 2  grftagNomFamille        1            35          48
# 3                          1            82          89
# 4                          1            90          98

# %%
casen_df.to_excel("casen_multiple_files.xlsx", index=False)

# %%
from tools import spacy_wrapper
importlib.reload(spacy_wrapper)
from tools.spacy_wrapper import SpaCyConfig

# sp = SpaCyConfig(
#     model = "fr_core_news_sm",
#     production_mode = True,
#     timer = True,
#     logging = True,
#     verbose = True
# )

sp = SpaCyConfig()
sp_df = sp.run(DATAS)
sp_df.head()
# Out:
#        NER NER_label method  file_id  entity_start  entity_end
# 0    Sunny       PER  spaCy        0            35          40
# 1  Haffner       PER  spaCy        0           116         123
# 2    Sunny       LOC  spaCy        0           164         169
# 3     Nora       LOC  spaCy        0           206         210
# 4  Haffner       PER  spaCy        0           311         318

# %%
from tools import stanza_wrapper
importlib.reload(stanza_wrapper)
from tools.stanza_wrapper import StanzaConfig

# st = StanzaConfig(
#     use_gpu = True,
#     production_mode = True,
#     timer = False,
#     logging = False,
#     verbose = False
# )

st = StanzaConfig()
st_df = st.run(DATAS)
st_df.head()
# Out:
# 2025-06-17 12:42:35 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 432kB [00:00, 52.3MB/s]
# 2025-06-17 12:42:36 INFO: Downloaded file to C:\Users\valen\stanza_resources\resources.json
# 2025-06-17 12:42:36 INFO: Loading these models for language: fr (French):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | combined           |
# | mwt       | combined           |
# | ner       | wikinergold_charlm |
# ==================================
#
# 2025-06-17 12:42:36 WARNING: GPU requested, but is not available!
# 2025-06-17 12:42:36 INFO: Using device: cpu
# 2025-06-17 12:42:36 INFO: Loading: tokenize
# 2025-06-17 12:42:47 INFO: Loading: mwt
# 2025-06-17 12:42:47 INFO: Loading: ner
# 2025-06-17 12:42:50 INFO: Done loading processors!
#                NER NER_label  method  file_id  entity_start  entity_end
# 0             Ralf       PER  stanza        0             0           4
# 1            Sunny      MISC  stanza        0            35          40
# 2  affaire Haffner      MISC  stanza        0           108         123
# 3            Sunny       LOC  stanza        0           164         169
# 4             Nora       PER  stanza        0           206         210

# %%
sp_df = pd.read_excel("short_spacy.xlsx")
st_df = pd.read_excel("short_stanza.xlsx")

# %%
from tools import ner_config
importlib.reload(ner_config)
from tools.ner_config import NerConfig


ner = NerConfig(
    process_priority_merge = True,
    process_casen_opti = True,
    remove_duplicated_entity_per_desc = True,
    keep_only_trustable_methods = True,
    save_to_file = True,
    production_mode = True,
    logging = False,
    timer = False,
    verbose = True
)

ner_df = ner.run(data=DATAS, dfs=[casen_df, sp_df, st_df]) #, correction="./Results/NER_casEN_spaCy_stanza_PER_entity_track.xlsx"
ner_df.head()
# Out:
# [load config] Config Loaded sucessfuly !
# [merge] Shape of DataFrames : [(13233, 9), (20912, 6), (20316, 6)]
# [merge] Final merged DataFrame shape: (35643, 9)
# [merge] method value counts:
# method
# spaCy                 9476
# stanza                7391
# spaCy_stanza          5543
# casEN_spaCy_stanza    5523
# casEN                 5481
# casEN_stanza          1859
# casEN_spaCy            370
# Name: count, dtype: int64
# [casEN_optimisation] CasEN_opti only : 505 lignes
# [composite_entity_priority] Composite methods: ['spaCy_stanza', 'casEN_stanza', 'casEN_spaCy_stanza', 'casEN_spaCy']
# [composite_entity_priority] Atomic methods: ['stanza', 'spaCy', 'casEN']
# [composite_entity_priority] Updated 1300 rows to _priority.
# [composite_entity_priority] spaCy : 9476 lignes
# [composite_entity_priority] stanza : 7391 lignes
# [composite_entity_priority] casEN_spaCy_stanza : 5523 lignes
# [composite_entity_priority] spaCy_stanza : 5472 lignes
# [composite_entity_priority] casEN : 4976 lignes
# [composite_entity_priority] casEN_stanza_priority : 1119 lignes
# [composite_entity_priority] casEN_stanza : 740 lignes
# [composite_entity_priority] casEN_opti : 505 lignes
# [composite_entity_priority] casEN_spaCy : 260 lignes
# [composite_entity_priority] casEN_spaCy_priority : 110 lignes
# [composite_entity_priority] spaCy_stanza_priority : 71 lignes
# Trustable methods : ['casEN_opti', 'casEN_spaCy_stanza', 'casEN_stanza_priority', 'casEN_stanza', 'spaCy_stanza_priority']
# [cleaning] 27685 rows were removed
# [cleaning] 872 Duplicated rows were removed
# Missing columns : ['titles', 'sub_title', 'days', 'channel', 'category', 'clean_titles']
# [columns] Final columns in df: ['titles', 'sub_title', 'days', 'channel', 'category', 'NER', 'NER_label', 'clean_titles', 'method', 'file_id']
# File saved at : Results\20231101_priority_CasenOpti_TrustMethods_prod.xlsx
#                            titles  \
# 7                Faster than fear
# 9                Faster than fear
# 11  Commissaire Magellan (S1-E30)
# 14  Commissaire Magellan (S1-E30)
# 15  Commissaire Magellan (S1-E30)
#
#                                             sub_title      days    channel  \
# 7   Série TV\nSérie policière\nRéalisateur :\nFlor...  20231101  13eme RUE
# 9   Série TV\nSérie policière\nRéalisateur :\nFlor...  20231101  13eme RUE
# 11  Série TV\nSérie policière\nDurée : 1h40min\nRé...  20231101  13eme RUE
# 14  Série TV\nSérie policière\nDurée : 1h40min\nRé...  20231101  13eme RUE
# 15  Série TV\nSérie policière\nDurée : 1h40min\nRé...  20231101  13eme RUE
#
#     category               NER NER_label          clean_titles  \
# 7   Série TV              Nora       PER      Faster than fear
# 9   Série TV            Marcel       PER      Faster than fear
# 11  Série TV     Tristan Garil       PER  Commissaire Magellan
# 14  Série TV          Delandin       PER  Commissaire Magellan
# 15  Série TV  Estelle Delandin       PER  Commissaire Magellan
#
#                    method  file_id
# 7   casEN_stanza_priority      0.0
# 9      casEN_spaCy_stanza      0.0
# 11           casEN_stanza      1.0
# 14  spaCy_stanza_priority      1.0
# 15     casEN_spaCy_stanza      1.0

# %%
from tools import ner_consensus
importlib.reload(ner_consensus)
from tools.ner_consensus import NER_Consensus


result_df =  NER_Consensus(DATAS)
result_df.head()
result_df.to_excel("NER_Consensus.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 importlib.reload(ner_consensus)
#       3 from tools.ner_consensus import NER_Consensus
# ----> 6 result_df =  NER_Consensus(DATAS)
#
# NameError: name 'DATAS' is not defined
