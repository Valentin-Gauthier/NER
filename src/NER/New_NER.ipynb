# %%
import importlib
import pandas as pd

# %%
# LOAD THE DATAS
DATAS = pd.read_excel(EXCEL_DATA)

# %%
from tools import ner_config2
importlib.reload(ner_config2)
from tools.ner_config2 import NerConfig
